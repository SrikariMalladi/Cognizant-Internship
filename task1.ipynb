# %% [markdown]
# <a href="https://colab.research.google.com/github/SrikariMalladi/Cognizant-Internship/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1

# %% [markdown]
# **SETTING** **UP**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a127bc6-9397-4107-8c67-042b8713c672" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a127bc6-9397-4107-8c67-042b8713c672">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **IMPORTING** **FILES**

# %%
import pandas as pd

# Assuming you uploaded a CSV file named "example.csv"
df = pd.read_csv("4.1 sample_sales_data.csv")

# %% [markdown]
# DATA LOADING

# %%
df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')
df.head()
# Out:
#                          transaction_id            timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# 1         1   3.99     e-wallet
# 2         2   0.38     e-wallet
# ...

# %%
df.head(10)
# Out:
#                          transaction_id            timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
# 5  b5b3c8b9-f496-484d-aa30-4f2efb5ed56c  2022-03-07 17:59:47
# 6  4997b1ae-f5aa-4b9f-8fc8-22ad8f19837c  2022-03-07 19:36:57
# 7  bfffee68-0736-42af-bd3e-4ca77541b0d6  2022-03-07 19:03:20
# 8  ce50e984-90cd-4b47-8537-3a4e32e6d314  2022-03-07 11:34:32
# 9  f0700cc9-e6f5-4b9a-add4-05e64b4f495b  2022-03-07 09:20:12
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# ...

# %%
df.tail()
# Out:
#                             transaction_id            timestamp  \
# 7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  2022-03-03 18:22:09
# 7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  2022-03-04 19:14:46
# 7826  79aee7d6-1405-4345-9a15-92541e9e1e74  2022-03-03 14:00:09
# 7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  2022-03-04 15:11:38
# 7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  2022-03-06 13:50:36
#
#                                 product_id           category customer_type  \
# 7824  bc6187a9-d508-482b-9ca6-590d1cc7524f  cleaning products         basic
# 7825  707e4237-191c-4cc9-85af-383a6c1cb2ab  cleaning products      standard
# 7826  a9325c1a-2715-41df-b7f4-3078fa5ecd97  cleaning products         basic
# 7827  707e4237-191c-4cc9-85af-383a6c1cb2ab  cleaning products         basic
# 7828  d6ccd088-11be-4c25-aa1f-ea87c01a04db  cleaning products    non-member
#
#       unit_price  quantity  total payment_type
# 7824       14.19         2  28.38     e-wallet
# ...

# %%
df.tail(5)
# Out:
#                             transaction_id            timestamp  \
# 7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  2022-03-03 18:22:09
# 7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  2022-03-04 19:14:46
# 7826  79aee7d6-1405-4345-9a15-92541e9e1e74  2022-03-03 14:00:09
# 7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  2022-03-04 15:11:38
# 7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  2022-03-06 13:50:36
#
#                                 product_id           category customer_type  \
# 7824  bc6187a9-d508-482b-9ca6-590d1cc7524f  cleaning products         basic
# 7825  707e4237-191c-4cc9-85af-383a6c1cb2ab  cleaning products      standard
# 7826  a9325c1a-2715-41df-b7f4-3078fa5ecd97  cleaning products         basic
# 7827  707e4237-191c-4cc9-85af-383a6c1cb2ab  cleaning products         basic
# 7828  d6ccd088-11be-4c25-aa1f-ea87c01a04db  cleaning products    non-member
#
#       unit_price  quantity  total payment_type
# 7824       14.19         2  28.38     e-wallet
# ...

# %%
# Get information about the DataFrame
print(df.info())

# Describe numerical columns
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7829 entries, 0 to 7828
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  7829 non-null   object
#  1   timestamp       7829 non-null   object
#  2   product_id      7829 non-null   object
#  3   category        7829 non-null   object
#  4   customer_type   7829 non-null   object
#  5   unit_price      7829 non-null   float64
#  6   quantity        7829 non-null   int64
#  7   total           7829 non-null   float64
#  8   payment_type    7829 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 550.6+ KB
# None
#         unit_price     quantity        total
# count  7829.000000  7829.000000  7829.000000
# mean      7.819480     2.501597    19.709905
# std       5.388088     1.122722    17.446680
# min       0.190000     1.000000     0.190000
# 25%       3.990000     1.000000     6.570000
# ...

# %%
# Count null values in each column
null_counts = df.isnull().sum()

# Print the count of null values for each column
print("Null value counts per column:")
print(null_counts)
# Out:
# Null value counts per column:
# transaction_id    0
# timestamp         0
# product_id        0
# category          0
# customer_type     0
# unit_price        0
# quantity          0
# total             0
# payment_type      0
# dtype: int64

# %%
# Get data types of each column
data_types = df.dtypes

# Print the data types of each column
print("Data types of each column:")
print(data_types)
# Out:
# Data types of each column:
# transaction_id     object
# timestamp          object
# product_id         object
# category           object
# customer_type      object
# unit_price        float64
# quantity            int64
# total             float64
# payment_type       object
# dtype: object

# %%
data.nunique()
# Out:
# transaction_id    5
# timestamp         5
# product_id        3
# category          3
# customer_type     2
# unit_price        5
# quantity          4
# total             5
# payment_type      2
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# transaction_id    0.0
# timestamp         0.0
# product_id        0.0
# category          0.0
# customer_type     0.0
# unit_price        0.0
# quantity          0.0
# total             0.0
# payment_type      0.0
# dtype: float64

# %% [markdown]
# Descriptive statistics

# %%
# Compute mean and median separately for specific columns
mean_unit_price = df['unit_price'].mean()
median_unit_price = df['unit_price'].median()

mean_quantity = df['quantity'].mean()
median_quantity = df['quantity'].median()

print("Mean of unit_price:", mean_unit_price)
print("Median of unit_price:", median_unit_price)

print("Mean of quantity:", mean_quantity)
print("Median of quantity:", median_quantity)
# Out:
# Mean of unit_price: 7.819480137948653
# Median of unit_price: 7.19
# Mean of quantity: 2.501596627921829
# Median of quantity: 3.0

# %%
# Compute count of non-null values for each numerical column
count = df.count()

# Print the count of non-null values for each numerical column
print("Count of non-null values for each numerical column:")
print(count)
# Out:
# Count of non-null values for each numerical column:
# transaction_id    7829
# timestamp         7829
# product_id        7829
# category          7829
# customer_type     7829
# unit_price        7829
# quantity          7829
# total             7829
# payment_type      7829
# dtype: int64

# %%
data.describe().T
# Out:
#            count                 mean                  min  \
# timestamp      5  2024-01-03 00:00:00  2024-01-01 00:00:00
# unit_price   5.0                12.99                 9.99
# quantity     5.0                  2.4                  1.0
# total        5.0               29.576                12.99
#
#                             25%                  50%                  75%  \
# timestamp   2024-01-02 00:00:00  2024-01-03 00:00:00  2024-01-04 00:00:00
# unit_price                10.99                12.99                14.99
# quantity                    2.0                  2.0                  3.0
# total                     29.98                31.98                32.97
#
#                             max        std
# timestamp   2024-01-05 00:00:00        NaN
# unit_price                15.99    2.54951
# quantity                    4.0   1.140175
# total                     39.96  10.004805

# %% [markdown]
# **Visualisation**

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
def plot_continuous_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8):
  _ = sns.displot(data, x=column, kde=True, height=height, aspect=height/5).set(title=f'Distribution of {column}');

def get_unique_values(data, column):
  num_unique_values = len(data[column].unique())
  value_counts = data[column].value_counts()
  print(f"Column: {column} has {num_unique_values} unique values\n")
  print(value_counts)

def plot_categorical_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8, aspect: int = 2):
  _ = sns.catplot(data=data, x=column, kind='count', height=height, aspect=aspect).set(title=f'Distribution of {column}');

def correlation_plot(data: pd.DataFrame = None):
  corr = df.corr()
  corr.style.background_gradient(cmap='coolwarm')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
df = pd.read_csv("4.1 sample_sales_data.csv")


# 1. Histogram
plt.hist(df['unit_price'], bins=10)
plt.xlabel('Unit Price')
plt.ylabel('Frequency')
plt.title('Histogram of Unit Price')
plt.show()

# 2. Bar Chart
plt.figure(figsize=(8, 6))
sns.countplot(x='category', data=df)
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Bar Chart of Categories')
plt.show()

# 4. Scatter Plot
plt.scatter(df['unit_price'], df['quantity'])
plt.xlabel('Unit Price')
plt.ylabel('Quantity')
plt.title('Scatter Plot of Unit Price vs Quantity')
plt.show()

# 5. Box Plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='category', y='quantity', data=df)
plt.xlabel('Category')
plt.ylabel('Quantity')
plt.title('Box Plot of Quantity by Category')
plt.show()

# 6. Pie Chart
plt.figure(figsize=(8, 6))
df['customer_type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie Chart of Customer Types')
plt.ylabel('')
plt.show()

# 7. Heatmap
plt.figure(figsize=(10, 8))
numeric_df = df.select_dtypes(include=['number'])  # Select numeric columns only
sns.heatmap(numeric_df.corr(), annot=True, cmap='viridis', fmt=".2f")  # Use 'viridis' colormap
plt.title('Correlation Heatmap')
plt.show()

# 8. Stacked Bar Chart
plt.figure(figsize=(8, 6))
df.groupby(['category', 'payment_type']).size().unstack().plot(kind='bar', stacked=True)
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Stacked Bar Chart of Payment Types by Category')
plt.show()

# 10. Violin Plot
plt.figure(figsize=(8, 6))
sns.violinplot(x='customer_type', y='unit_price', data=df)
plt.xlabel('Customer Type')
plt.ylabel('Unit Price')
plt.title('Violin Plot of Unit Price by Customer Type')
plt.show()
